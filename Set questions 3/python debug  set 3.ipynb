# %%
#1.What is wrong with the following function definition, and how do you fix it?


def say_hello(name):
    print("Hello, " + name)

# %%
#2.What error will occur in the following code, and how do you fix it?


age = 25
print("I am " + age + " years old")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 #2.What error will occur in the following code, and how do you fix it?
#       4 age = 25
# ----> 5 print("I am " + age + " years old")
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 25
print("I am " , age , " years old")
# Out:
# I am  25  years old

# %%
#3.Question:
#What is the issue with the following code?

def greet():
    message = "Hello"
print(message)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       4 def greet():
#       5     message = "Hello"
# ----> 6 print(message)
#
# NameError: name 'message' is not defined

# %%
def greet():
    message = "Hello"
    return message

message = greet()
print (message)
# Out:
# Hello

# %%
#4.What error will occur in the following code, and how do you fix it?

def add(a, b):
    return a + b

print(add(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3 def add(a, b):
#       4     return a + b
# ----> 6 print(add(5))
#
# TypeError: add() missing 1 required positional argument: 'b'

# %%
# 2 input need to be given
print(add(5,6))
# Out:
# 11

# %%
#5.What is wrong with this code?

def is_even(n):
    if n % 2 == 1:
        return False
    else:
        return True
# logic is wrong. When reminder is 0 then True else False

# %%
#6.What happens when you run this code?

num = int("10a")
print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 #6.What happens when you run this code?
# ----> 3 num = int("10a")
#       4 print(num)
#
# ValueError: invalid literal for int() with base 10: '10a'

# %%
# There is non-numeric value which is trying to convert to integer which will not work
num = int("10")
print(num)
# Out:
# 10

# %%
#7.What will happen when you run the following code?


numbers = [1, 2, 3, 4]
numbers.sort().reverse()
print(numbers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 5
#       1 #7.What will happen when you run the following code?
#       4 numbers = [1, 2, 3, 4]
# ----> 5 numbers.sort().reverse()
#       6 print(numbers)
#
# AttributeError: 'NoneType' object has no attribute 'reverse'

# %%
numbers = [1, 2, 3, 4]
#sorted_number = numbers.sort()
#reversed_numbers = numbers.reverse()
numbers.sort()
print(numbers)
numbers.reverse()
print(numbers)
#print(sorted_number)  # sort functions returns None value
#print(reversed_numbers) # reverse functions also returns None value which will throw an error
# Out:
# [1, 2, 3, 4]
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?


numbers = [1, 2, 3]
numbers1 = numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#9.What will happen when you run the following code?


count = 10
def increment():
    count += 1
    print(count)

increment()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[30], line 9
#       6     count += 1
#       7     print(count)
# ----> 9 increment()
#
# Cell In[30], line 6, in increment()
#       5 def increment():
# ----> 6     count += 1
#       7     print(count)
#
# UnboundLocalError: cannot access local variable 'count' where it is not associated with a value

# %%
count=10
def increment():
    global count
    count += 1
    print(count)

increment()
# Out:
# 11

# %%
#10.What error will occur in the following code?

text = "Python"
#print(text[10])
# Out of range index error will show. Length of "Python" word is only 6. 
print(text[5]) # workable statment
# Out:
# n
