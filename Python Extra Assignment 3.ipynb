# %%
# print 'CORRECT' if i == 10
i = int(input("Enter your number="))
if(i==10):
    print("CORRECT")
# Out:
# Enter your number= 10
# CORRECT

# %%
# Check the password, using if and else 
Pwd = input("Enter your password=")
if (Pwd == 'HOPE@123'):
    print("Your Password is Correct")
else:
    print("Your Password is not Correct")
# Out:
# Enter your password= HOPE@123
# Your Password is Correct

# %%
 # Catagory the people by their age like children, adult, citizen, senior citizen... 
Age = int(input("Enter your age="))
if (Age<18):
    print("Children")
elif (Age<=35):
    print("Adult")
elif (Age<=59):
    print("Citizen")
else:
    prrint("Senior Citizen")
# Out:
# Enter your age= 20
# Adult

# %%
# Find whether given number is positive or negative 
Num1 = int(input("Enter your number ="))
if (Num1<0):
    print("The given Number:", Num1," is Negative")
else:
    print("The given Number:", Num1," is Positive")
# Out:
# Enter your number = 1
# The given Number: 1  is Positive

# %%
# Check whether the given number is divisible by 5 
Num1 = int(input("Enter your number ="))
if ((Num1 % 5)==0):
    print ("The given Number:", Num1," is Divisible by 5. Because reminder is 0")
else:
    print ("The given Number:", Num1," is not Divisible by 5. Because reminder is ", Num1%5,". Not 0")
# Out:
# Enter your number = 22
# The given Number: 22  is not Divisible by 5. Because reminder is  2 . Not 0
